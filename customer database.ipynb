# %%
import pandas as pd
import numpy as np

# %%
data =pd.read_csv("customer.csv")

# %%
data
# Out:
#      Rank               Title  Employees                      Sector  \
# 0       1             Walmart    2300000                   Retailing
# 1       2  Berkshire Hathaway     367700                  Financials
# 2       3               Apple     116000                  Technology
# 3       4         Exxon Mobil      72700                      Energy
# 4       5            McKesson      68000                 Wholesalers
# ..    ...                 ...        ...                         ...
# 495   496       Michaels Cos.      31000                   Retailing
# 496   497       Toll Brothers       4200  Engineering & Construction
# 497   498               Yahoo       8500                  Technology
# 498   499       Vistra Energy       4431                      Energy
# 499   500      ABM Industries     110000           Business Services
#
#                                      Industry         Hqlocation  Revenues  \
# ...

# %%
data.head(20)
# Out:
#     Rank                     Title  Employees                  Sector  \
# 0      1                   Walmart    2300000               Retailing
# 1      2        Berkshire Hathaway     367700              Financials
# 2      3                     Apple     116000              Technology
# 3      4               Exxon Mobil      72700                  Energy
# 4      5                  McKesson      68000             Wholesalers
# 5      6        UnitedHealth Group     230000             Health Care
# 6      7                CVS Health     204000             Health Care
# 7      8            General Motors     225000  Motor Vehicles & Parts
# 8      9                      AT&T     268540      Telecommunications
# 9     10                Ford Motor     201000  Motor Vehicles & Parts
# 10    11         AmerisourceBergen      18500             Wholesalers
# 11    12                Amazon.com     341400              Technology
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        500 non-null    int64
#  1   Title       500 non-null    object
#  2   Employees   500 non-null    int64
#  3   Sector      500 non-null    object
#  4   Industry    500 non-null    object
#  5   Hqlocation  500 non-null    object
#  6   Revenues    500 non-null    int64
#  7   Profits     500 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 31.4+ KB

# %%
data.describe()
# Out:
#              Rank     Employees       Revenues       Profits
# count  500.000000  5.000000e+02     500.000000    500.000000
# mean   250.492000  5.635013e+04   24111.748000   1779.479800
# std    144.477366  1.234520e+05   38337.353337   3937.558721
# min      1.000000  8.300000e+01    5145.000000  -6177.000000
# 25%    125.750000  1.190000e+04    7245.000000    235.725000
# 50%    250.500000  2.500000e+04   11384.000000    683.600000
# 75%    375.250000  5.682525e+04   22605.250000   1770.775000
# max    500.000000  2.300000e+06  485873.000000  45687.000000

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Employees', 'Sector', 'Industry', 'Hqlocation',
#        'Revenues', 'Profits'],
#       dtype='object')

# %%
data.head()
# Out:
#    Rank               Title  Employees       Sector  \
# 0     1             Walmart    2300000    Retailing
# 1     2  Berkshire Hathaway     367700   Financials
# 2     3               Apple     116000   Technology
# 3     4         Exxon Mobil      72700       Energy
# 4     5            McKesson      68000  Wholesalers
#
#                                    Industry         Hqlocation  Revenues  \
# 0                     General Merchandisers    Bentonville, AR    485873
# 1  Insurance: Property and Casualty (Stock)          Omaha, NE    223604
# 2               Computers, Office Equipment      Cupertino, CA    215639
# 3                        Petroleum Refining         Irving, TX    205004
# 4                  Wholesalers: Health Care  San Francisco, CA    192487
#
#    Profits
# 0  13643.0
# 1  24074.0
# 2  45687.0
# 3   7840.0
# 4   2258.0

# %%
data.shape
# Out:
# (500, 8)

# %%
data.sample()
# Out:
#      Rank         Title  Employees          Sector                 Industry  \
# 393   394  Ryder System      34500  Transportation  Trucking, Truck Leasing
#
#     Hqlocation  Revenues  Profits
# 393  Miami, FL      6787    262.5

# %%
data.isnull().sum()
# Out:
# Rank          0
# Title         0
# Employees     0
# Sector        0
# Industry      0
# Hqlocation    0
# Revenues      0
# Profits       0
# dtype: int64

# %%
data['Sector'].unique()
# Out:
# array(['Retailing', 'Financials', 'Technology', 'Energy', 'Wholesalers',
#        'Health Care', 'Motor Vehicles & Parts', 'Telecommunications',
#        'Industrials', 'Food & Drug Stores', 'Aerospace & Defense',
#        'Household Products', 'Food, Beverages & Tobacco',
#        'Transportation', 'Media', 'Chemicals', 'Apparel',
#        'Hotels, Restaurants & Leisure', 'Materials', 'Business Services',
#        'Engineering & Construction'], dtype=object)

# %%
data['Industry'].unique()
# Out:
# array(['General Merchandisers',
#        'Insurance: Property and Casualty (Stock)',
#        'Computers, Office Equipment', 'Petroleum Refining',
#        'Wholesalers: Health Care',
#        'Health Care: Insurance and Managed Care',
#        'Health Care: Pharmacy and Other Services',
#        'Motor Vehicles and Parts', 'Telecommunications',
#        'Internet Services and Retailing', 'Industrial Machinery',
#        'Food and Drug Stores', 'Diversified Financials',
#        'Commercial Banks', 'Specialty Retailers: Other',
#        'Aerospace and Defense', 'Computer Software',
#        'Information Technology Services',
#        'Insurance: Property and Casualty (Mutual)', 'Pharmaceuticals',
#        'Household and Personal Products',
#        'Insurance: Life, Health (Stock)', 'Food Consumer Products',
#        'Food Production', 'Mail, Package, and Freight Delivery',
#        'Semiconductors and Other Electronic Components', 'Entertainment',
# ...

# %%
sector=data.groupby('Sector')

# %%
sector

# %%
len(sector)
# Out:
# 21

# %%
sector.size().sort_values(ascending=False)
# Out:
# Sector
# Financials                       84
# Energy                           57
# Retailing                        47
# Technology                       43
# Health Care                      38
# Wholesalers                      29
# Food, Beverages & Tobacco        24
# Business Services                20
# Materials                        19
# Industrials                      19
# Transportation                   17
# Chemicals                        14
# Engineering & Construction       13
# Aerospace & Defense              12
# Household Products               12
# Media                            11
# Telecommunications               10
# Hotels, Restaurants & Leisure    10
# Motor Vehicles & Parts            9
# Food & Drug Stores                7
# Apparel                           5
# dtype: int64

# %%
sector.first()
# Out:
#                                Rank                     Title  Employees  \
# Sector
# Aerospace & Defense              24                    Boeing     150540
# Apparel                          88                      Nike      70700
# Business Services               146             ManpowerGroup      28000
# Chemicals                        62              Dow Chemical      56000
# Energy                            4               Exxon Mobil      72700
# Engineering & Construction      149                     Fluor      61551
# Financials                        2        Berkshire Hathaway     367700
# Food & Drug Stores               17  Walgreens Boots Alliance     300000
# Food, Beverages & Tobacco        44                   PepsiCo     264000
# Health Care                       6        UnitedHealth Group     230000
# Hotels, Restaurants & Leisure   112                McDonald’s     375000
# Household Products               36          Procter & Gamble     105000
# ...

# %%
sector.first(5)
# Out:
#                                Rank  Employees  Revenues  Profits
# Sector
# Aerospace & Defense              24     150540     94571   4895.0
# Apparel                          88      70700     32376   3760.0
# Business Services               146      28000     19654    443.7
# Chemicals                        62      56000     48158   4318.0
# Energy                            4      72700    205004   7840.0
# Engineering & Construction      149      61551     19037    281.4
# Financials                        2     367700    223604  24074.0
# Food & Drug Stores               17     300000    117351   4173.0
# Food, Beverages & Tobacco        44     264000     62799   6329.0
# Health Care                       6     230000    184840   7017.0
# Hotels, Restaurants & Leisure   112     375000     24622   4686.5
# Household Products               36     105000     71726  10508.0
# Industrials                      13     295000    126661   8831.0
# ...

# %%
sector.last()
# Out:
#                                Rank                               Title  \
# Sector
# Aerospace & Defense             492                    Rockwell Collins
# Apparel                         432                         Hanesbrands
# Business Services               500                      ABM Industries
# Chemicals                       484                            Celanese
# Energy                          499                       Vistra Energy
# Engineering & Construction      497                       Toll Brothers
# Financials                      483  Western & Southern Financial Group
# Food & Drug Stores              176                  Whole Foods Market
# Food, Beverages & Tobacco       486                            Seaboard
# Health Care                     454                  Genesis Healthcare
# Hotels, Restaurants & Leisure   461                   Wyndham Worldwide
# Household Products              474                              Mattel
# ...

# %%
sector.groups
# Out:
# {'Aerospace & Defense': [23, 49, 55, 89, 113, 115, 199, 227, 272, 379, 392, 491], 'Apparel': [87, 229, 334, 370, 431], 'Business Services': [145, 178, 186, 191, 200, 239, 241, 263, 266, 298, 300, 344, 377, 451, 458, 470, 477, 489, 492, 499], 'Chemicals': [61, 112, 182, 203, 210, 235, 274, 288, 293, 308, 376, 466, 481, 483], 'Energy': [3, 18, 33, 36, 50, 78, 88, 102, 114, 116, 120, 121, 140, 144, 156, 166, 169, 171, 172, 174, 193, 195, 214, 228, 230, 233, 234, 236, 237, 255, 262, 271, 273, 277, 279, 284, 307, 311, 327, 342, 343, 348, 355, 357, 361, 364, 366, 367, 374, 399, 401, 418, 430, 456, 479, 487, 498], 'Engineering & Construction': [148, 160, 231, 258, 259, 323, 352, 354, 359, 414, 445, 493, 496], 'Financials': [1, 19, 20, 24, 25, 29, 32, 38, 41, 47, 54, 64, 67, 74, 75, 76, 77, 79, 83, 85, 96, 98, 99, 101, 119, 124, 125, 152, 165, 167, 176, 184, 188, 206, 209, 212, 213, 217, 221, 226, 238, 244, 245, 254, 257, 261, 265, 270, 276, 285, 292, 301, 302, 314, 315, 328, 341, 353, 356, 
# ...

# %%
data.iloc[23]
# Out:
# Rank                             24
# Title                        Boeing
# Employees                    150540
# Sector          Aerospace & Defense
# Industry      Aerospace and Defense
# Hqlocation              Chicago, IL
# Revenues                      94571
# Profits                      4895.0
# Name: 23, dtype: object

# %%
data.iloc[460]
# Out:
# Rank                                    461
# Title                     Wyndham Worldwide
# Employees                             37800
# Sector        Hotels, Restaurants & Leisure
# Industry           Hotels, Casinos, Resorts
# Hqlocation                   Parsippany, NJ
# Revenues                               5599
# Profits                               611.0
# Name: 460, dtype: object

# %%
sector.get_group('Technology')
# Out:
#      Rank                           Title  Employees      Sector  \
# 2       3                           Apple     116000  Technology
# 11     12                      Amazon.com     341400  Technology
# 26     27                        Alphabet      72053  Technology
# 27     28                       Microsoft     114000  Technology
# 31     32                             IBM     414400  Technology
# 40     41               Dell Technologies     138000  Technology
# 46     47                           Intel     106000  Technology
# 58     59      Hewlett Packard Enterprise     195000  Technology
# 59     60                   Cisco Systems      73700  Technology
# 60     61                              HP      49000  Technology
# 80     81                          Oracle     136000  Technology
# 97     98                        Facebook      17048  Technology
# 118   119                        Qualcomm      30500  Technology
# ...

# %%
sector.get_group('Apparel')
# Out:
#      Rank         Title  Employees   Sector Industry         Hqlocation  \
# 87     88          Nike      70700  Apparel  Apparel      Beaverton, OR
# 229   230            VF      69000  Apparel  Apparel     Greensboro, NC
# 334   335           PVH      26650  Apparel  Apparel       New York, NY
# 370   371  Ralph Lauren      20500  Apparel  Apparel       New York, NY
# 431   432   Hanesbrands      67800  Apparel  Apparel  Winston-Salem, NC
#
#      Revenues  Profits
# 87      32376   3760.0
# 229     12207   1074.1
# 334      8203    549.0
# 370      7405    396.0
# 431      6063    539.4

# %%
sector.get_group('Apparel').shape[0]
# Out:
# 5

# %%
sector.get_group('Apparel').sum()
# Out:
# Rank                                                       1456
# Title                          NikeVFPVHRalph LaurenHanesbrands
# Employees                                                254650
# Sector                      ApparelApparelApparelApparelApparel
# Industry                    ApparelApparelApparelApparelApparel
# Hqlocation    Beaverton, ORGreensboro, NCNew York, NYNew Yor...
# Revenues                                                  66254
# Profits                                                  6318.5
# dtype: object

# %%
sector['Revenues'].sum().sort_values(ascending=True)
# Out:
# Sector
# Apparel                            66254
# Hotels, Restaurants & Leisure     121189
# Engineering & Construction        124682
# Materials                         169755
# Media                             180767
# Household Products                180846
# Chemicals                         188667
# Business Services                 194685
# Aerospace & Defense               338302
# Transportation                    354733
# Food & Drug Stores                389686
# Motor Vehicles & Parts            392466
# Industrials                       418359
# Telecommunications                459978
# Food, Beverages & Tobacco         472806
# Wholesalers                       799416
# Energy                           1176417
# Technology                       1257589
# Health Care                      1318389
# Retailing                        1383281
# Financials                       2067607
# Name: Revenues, dtype: int64

# %%
sector['Profits'].sum().sort_values(ascending=True)
# Out:
# Sector
# Energy                              370.6
# Engineering & Construction         5072.2
# Materials                          5176.9
# Apparel                            6318.5
# Food & Drug Stores                 8522.0
# Wholesalers                       11347.1
# Hotels, Restaurants & Leisure     14510.6
# Chemicals                         15918.3
# Motor Vehicles & Parts            17275.8
# Household Products                19803.7
# Media                             20034.7
# Business Services                 23107.1
# Aerospace & Defense               25119.7
# Transportation                    28395.0
# Industrials                       32826.1
# Telecommunications                41272.8
# Retailing                         46613.9
# Food, Beverages & Tobacco         56308.4
# Health Care                      105383.9
# Technology                       177901.4
# Financials                       228461.2
# Name: Profits, dtype: float64
